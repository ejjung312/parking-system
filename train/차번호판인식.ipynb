# %% [markdown]
# # YOLO 다운로드

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 43.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 48.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 79.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 90.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %% [markdown]
# # 차번호 데이터 다운로드

# %%
# !curl -L "https://universe.roboflow.com/ds/f9288I86ji?key=lGAd0IZ3AV" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: train/labels/xemay821_jpg.rf.db63cb09c0a73022fad9762c9df353ca.txt
#   inflating: train/labels/xemay821_jpg.rf.e25e0f645a3c2b48129c844582d2d23f.txt
#   inflating: train/labels/xemay823_jpg.rf.0be3eec63e5a757cc80e451231ea6b8e.txt
#   inflating: train/labels/xemay823_jpg.rf.8fa3edc9b43a571b263439a54bfaad46.txt
#   inflating: train/labels/xemay823_jpg.rf.de5980c40766ddf98209e1ab810004e4.txt
#   inflating: train/labels/xemay824_jpg.rf.56c71c5aa44c60811611ee6137d01305.txt
#   inflating: train/labels/xemay824_jpg.rf.8d444e5ead7b14d13a576be2925f4ac1.txt
#   inflating: train/labels/xemay824_jpg.rf.fe7cf142fdfef2ac16afea9f069625d6.txt
#   inflating: train/labels/xemay826_jpg.rf.0e9c15bafbd28a4ce0163dbc729acf67.txt
#   inflating: train/labels/xemay826_jpg.rf.98b69cbf4d66593a8f0a2130198c2481.txt
#   inflating: train/labels/xemay826_jpg.rf.e78da628c0f7c7800d3fbc403294f2d0.txt
# ...

# %%
from glob import glob

train_img_list = glob('/content/train/images/*.jpg')
train_txt_list = glob('/content/train/labels/*.txt')

val_img_list = glob('/content/valid/images/*.jpg')
val_txt_list = glob('/content/valid/labels/*.txt')

print(len(train_img_list), len(train_txt_list))
print(len(val_img_list), len(val_txt_list))
# Out:
# 21173 21173
# 2046 2046

# %% [markdown]
# # train.txt, val.txt 생성

# %%
from glob import glob

train_img_list = glob('/content/train/images/*.jpg')
val_img_list = glob('/content/valid/images/*.jpg')
test_img_list = glob('/content/test/images/*.jpg')

train_txt_list = glob('/content/train/labels/*.txt')
val_txt_list = glob('/content/valid/labels/*.txt')
test_txt_list = glob('/content/test/labels/*.txt')

# 파일쓰기
with open('train.txt', 'w') as f:
  f.write('\n'.join(train_img_list)+'\n')

with open('val.txt', 'w') as f:
  f.write('\n'.join(val_img_list)+'\n')

with open('test.txt', 'w') as f:
  f.write('\n'.join(test_txt_list)+'\n')

# %% [markdown]
# # data.yaml 수정

# %%
import yaml

with open('/content/data.yaml', 'r') as f:
  data = yaml.full_load(f)

data['names'] = ['license_plate']

data['train'] = '/content/train.txt'
data['val'] = '/content/val.txt'
data['test'] = '/content/test.txt'

with open('/content/data.yaml', 'w') as f:
  data = yaml.dump(data, f)

# %% [markdown]
# # 훈련

# %%
# !yolo train data='/content/data.yaml' epochs=100 batch=16
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# WARNING ⚠️ 'model' argument is missing. Using default 'model=yolo11n.pt'.
# ...
# 100% 5.35M/5.35M [00:00<00:00, 422MB/s]
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # 다운로드

# %%
from google.colab import files

# !zip -r /content/result.zip /content/runs/

files.download('/content/result.zip')
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/detect/ (stored 0%)
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 4%)
#   adding: content/runs/detect/train/results.csv (deflated 63%)
#   adding: content/runs/detect/train/labels.jpg (deflated 39%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 3%)
#   adding: content/runs/detect/train/args.yaml (deflated 53%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 2%)
#   adding: content/runs/detect/train/events.out.tfevents.1738374110.1986eb34499d.7772.0 (deflated 91%)
#   adding: content/runs/detect/train/weights/ (stored 0%)
#   adding: content/runs/detect/train/weights/best.pt (deflated 9%)
#   adding: content/runs/detect/train/weights/last.pt (deflated 9%)
#   adding: content/runs/detect/train/labels_correlogram.jpg (deflated 30%)
